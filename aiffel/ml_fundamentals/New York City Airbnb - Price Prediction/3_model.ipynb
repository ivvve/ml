# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 피쳐 전처리

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

def remove_outlier(data_df):
    data_df = data_df.copy()
    data_df = data_df.drop(data_df[data_df["minimum_nights"] > 400].index)
    data_df = data_df.drop(data_df[data_df["price"] > 5000].index)
    return data_df

def preprocess_data(X, is_train):
    X = X.copy()

    # 사용하지 않는 피쳐 제거
    X = X.drop(columns=[
        "id",
        "name",
        "host_id",
        "host_name",
        "calculated_host_listings_count",
        "neighbourhood",
        "availability_365",
        "last_review",
    ])

    # neighbourhood_group: one-hot encoding
    X = pd.get_dummies(X, columns=["neighbourhood_group"], drop_first=True)

    # room_type one-hot encoding
    X = pd.get_dummies(X, columns=["room_type"], drop_first=True)

    # mimimum_nights: log 변환
    X["minimum_nights"] = np.log1p(X["minimum_nights"])

    # number_of_reviews, reviews_per_month: 차원 축소 및 log 변환
    X = X.drop(columns=["reviews_per_month"])
    X["number_of_reviews"] = np.log1p(X["number_of_reviews"])

    # feature scaling
    numeric_features = X.select_dtypes("number").columns.tolist()
    if is_train:
        scaler.fit(X[numeric_features])
    X[numeric_features] = scaler.transform(X[numeric_features])

    return X

# %%
train_df = pd.read_csv("./data/train.csv")
test_df = pd.read_csv("./data/test.csv")
y_test_df = pd.read_csv("./data/y_test.csv")

# train
train_df = remove_outlier(train_df)
X_train = train_df.drop(columns=["price"])
X_train = preprocess_data(X_train, is_train=True)
y_train = train_df["price"]

# test
X_test = test_df.copy()
X_test = preprocess_data(X_test, is_train=False)
y_test = y_test_df.copy()["price"]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((39092, 10), (39092,), (9779, 10), (9779,))

# %% [markdown]
# ## baseline model과 비교

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

model = XGBRegressor(random_state=2022)

model.fit(X_train, y_train)
pred = model.predict(X_test)
mean_squared_error(y_test, pred)
# Out:
# 48387.558380601826

# %% [markdown]
# ## Model 최적화

# %%
from pycaret.regression import *

reg = setup(data=X_train, target=y_train,
            train_size=0.8, fold=5, 
            n_jobs=-1,
            session_id=42)

best_models = compare_models(sort="mse", n_select=3)
best_models
# Out:
# <style type="text/css">
# #T_d050f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d050f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d050f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d050f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d050f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d050f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d050f_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d050f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d050f_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d050f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d050f_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d050f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d050f_row3_col1" class="data row3 col1" >(39092, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d050f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d050f_row4_col1" class="data row4 col1" >(39092, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d050f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d050f_row5_col1" class="data row5 col1" >(31273, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d050f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d050f_row6_col1" class="data row6 col1" >(7819, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d050f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d050f_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d050f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d050f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d050f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d050f_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d050f_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d050f_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d050f_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d050f_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d050f_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d050f_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d050f_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d050f_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d050f_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d050f_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d050f_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d050f_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d050f_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d050f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d050f_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d050f_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d050f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d050f_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d050f_row18_col1" class="data row18 col1" >d713</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d8b5d th {
#   text-align: left;
# }
# #T_d8b5d_row0_col0, #T_d8b5d_row0_col1, #T_d8b5d_row0_col6, #T_d8b5d_row1_col0, #T_d8b5d_row1_col1, #T_d8b5d_row1_col2, #T_d8b5d_row1_col3, #T_d8b5d_row1_col4, #T_d8b5d_row1_col5, #T_d8b5d_row1_col6, #T_d8b5d_row2_col0, #T_d8b5d_row2_col1, #T_d8b5d_row2_col2, #T_d8b5d_row2_col3, #T_d8b5d_row2_col4, #T_d8b5d_row2_col5, #T_d8b5d_row2_col6, #T_d8b5d_row3_col0, #T_d8b5d_row3_col1, #T_d8b5d_row3_col2, #T_d8b5d_row3_col3, #T_d
col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_d8b5d_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_d8b5d_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_d8b5d_row5_col1" class="data row5 col1" >68.1326</td>
#       <td id="T_d8b5d_row5_col2" class="data row5 col2" >26462.8053</td>
#       <td id="T_d8b5d_row5_col3" class="data row5 col3" >161.5956</td>
#       <td id="T_d8b5d_row5_col4" class="data row5 col4" >0.1592</td>
#       <td id="T_d8b5d_row5_col5" class="data row5 col5" >0.
# [LGBMRegressor(n_jobs=-1, random_state=42),
#  GradientBoostingRegressor(random_state=42),
#  Ridge(random_state=42)]

# %%
best_tuned_models = [tune_model(m) for m in best_models]
blended_model = blend_models(best_tuned_models)
model = finalize_model(blended_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              16:22:28
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_fa60c_row5_col0, #T_fa60c_row5_col1, #T_fa60c_row5_col2, #T_fa60c_row5_col3, #T_fa60c_row5_col4, #T_fa60c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fa60c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa60c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fa60c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fa60c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fa60c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fa60c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fa60c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa60c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa60c_row0_col0" class="data row0 col0" >63.2083</td>
#       <td id="T_fa60c_row0_col1" class="data row0 col1" >25772.7970</td>
#       <td id="T_fa60c_row0_col2" class="data row0 col2" >160.5391</td>
#       <td id="T_fa60c_row0_col3" class="data row0 col3" >0.1769</td>
#       <td id="T_fa60c_row0_col4" class="data row0 col4" >0.5038</td>
#       <td id="T_fa60c_row0_col5" class="data row0 col5" >0.4431</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa60c_row1_col0" class="data row1 col0" >62.7859</td>
#       <td id="T_fa60c_row1_col1" class="data row1 col1" >23920.9140</td>
#       <td id="T_fa60c_row1_col2" class="data row1 col2" >154.6639</td>
#       <td id="T_fa60c_row1_col3" class="data row1 col3" >0.2017</td>
#       <td id="T_fa60c_row1_col4" class="data row1 col4" >0.4972</td>
#       <td id="T_fa60c_row1_col5" class="data row1 col5" >0.4523</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa60c_row2_col0" class="data row2 col0" >66.2574</td>
#       <td id="T_fa60c_row2_col1" class="data row2 col1" >31032.0666</td>
#       <td id="T_fa60c_row2_col2" class="data row2 col2" >176.1592</td>
#       <td id="T_fa60c_row2_col3" class="data row2 col3" >0.1874</td>
#       <td id="T_fa60c_row2_col4" class="data row2 col4" >0.4959</td>
#       <td id="T_fa60c_row2_col5" class="data row2 col5" >0.4498</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa60c_row3_col0" class="data row3 col0" >62.2274</td>
#       <td id="T_fa60c_row3_col1" class="data row3 col1" >15649.8220</td>
#       <td id="T_fa60c_row3_col2" class="data row3 col2" >125.0992</td>
#       <td id="T_fa60c_row3_col3" class="data row3 col3" >0.2400</td>
#       <td id="T_fa60c_row3_col4" class="data row3 col4" >0.4977</td>
#       <td id="T_fa60c_row3_col5" class="data row3 col5" >0.4702</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa60c_row4_col0" class="data row4 col0" >64.1561</td>
#       <td id="T_fa60c_row4_col1" class="data row4 col1" >29658.6225</td>
#       <td id="T_fa60c_row4_col2" class="data row4 col2" >172.2168</td>
#       <td id="T_fa60c_row4_col3" class="data row4 col3" >0.1874</td>
#       <td id="T_fa60c_row4_col4" class="data row4 col4" >0.4883</td>
#       <td id="T_fa60c_row4_col5" class="data row4 col5" >0.4428</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fa60c_row5_col0" class="data row5 col0" >63.7270</td>
#       <td id="T_fa60c_row5_col1" class="data row5 col1" >25206.8444</td>
#       <td id="T_fa60c_row5_col2" class="data row5 col2" >157.7356</td>
#       <td id="T_fa60c_row5_col3" class="data row5 col3" >0.1987</td>
#       <td id="T_fa60c_row5_col4" class="data row5 col4" >0.4966</td>
#       <td id="T_fa60c_row5_col5" class="data row5 col5" >0.4516</td>
#     </tr>
#     <tr>
#       <th id="T_fa60c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fa60c_row6_col0" class="data row6 col0" >1.4136</td>
#       <td id="T_fa60c_row6_col1" class="data row6 col1" >5423.3226</td>
#       <td id="T_fa60c_row6_col2" class="data row6 col2" >18.0641</td>
#       <td id="T_fa60c_row6_col3" class="data row6 col3" >0.0221</td>
#       <td id="T_fa60c_row6_col4" class="data row6 col4" >0.0049</td>
#       <td id="T_fa60c_row6_col5" class="data row6 col5" >0.0100</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# <style type="text/css">
# #T_0a12f_row5_col0, #T_0a12f_row5_col1, #T_0a12f_row5_col2, #T_0a12f_row5_col3, #T_0a12f_row5_col4, #T_0a12f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0a12f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a12f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0a12f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0a12f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0a12f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0a12f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0a12f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a12f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a12f_row0_col0" class="data row0 col0" >63.8278</td>
#       <td id="T_0a12f_row0_col1" class="data row0 col1" >26033.6397</td>
#       <td id="T_0a12f_row0_col2" class="data row0 col2" >161.3494</td>
#       <td id="T_0a12f_row0_col3" class="data row0 col3" >0.1686</td>
#       <td id="T_0a12f_row0_col4" class="data row0 col4" >0.5075</td>
#       <td id="T_0a12f_row0_col5" class="data row0 col5" >0.4496</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a12f_row1_col0" class="data row1 col0" >63.0549</td>
#       <td id="T_0a12f_row1_col1" class="data row1 col1" >24248.1523</td>
#       <td id="T_0a12f_row1_col2" class="data row1 col2" >155.7182</td>
#       <td id="T_0a12f_row1_col3" class="data row1 col3" >0.1908</td>
#       <td id="T_0a12f_row1_col4" class="data row1 col4" >0.4985</td>
#       <td id="T_0a12f_row1_col5" class="data row1 col5" >0.4547</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a12f_row2_col0" class="data row2 col0" >66.5684</td>
#       <td id="T_0a12f_row2_col1" class="data row2 col1" >31613.5608</td>
#       <td id="T_0a12f_row2_col2" class="data row2 col2" >177.8020</td>
#       <td id="T_0a12f_row2_col3" class="data row2 col3" >0.1722</td>
#       <td id="T_0a12f_row2_col4" class="data row2 col4" >0.4979</td>
#       <td id="T_0a12f_row2_col5" class="data row2 col5" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a12f_row3_col0" class="data row3 col0" >62.0691</td>
#       <td id="T_0a12f_row3_col1" class="data row3 col1" >16113.9815</td>
#       <td id="T_0a12f_row3_col2" class="data row3 col2" >126.9409</td>
#       <td id="T_0a12f_row3_col3" class="data row3 col3" >0.2174</td>
#       <td id="T_0a12f_row3_col4" class="data row3 col4" >0.4971</td>
#       <td id="T_0a12f_row3_col5" class="data row3 col5" >0.4663</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a12f_row4_col0" class="data row4 col0" >64.3011</td>
#       <td id="T_0a12f_row4_col1" class="data row4 col1" >30302.3360</td>
#       <td id="T_0a12f_row4_col2" class="data row4 col2" >174.0757</td>
#       <td id="T_0a12f_row4_col3" class="data row4 col3" >0.1698</td>
#       <td id="T_0a12f_row4_col4" class="data row4 col4" >0.4911</td>
#       <td id="T_0a12f_row4_col5" class="data row4 col5" >0.4424</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_0a12f_row5_col0" class="data row5 col0" >63.9643</td>
#       <td id="T_0a12f_row5_col1" class="data row5 col1" >25662.3341</td>
#       <td id="T_0a12f_row5_col2" class="data row5 col2" >159.1772</td>
#       <td id="T_0a12f_row5_col3" class="data row5 col3" >0.1838</td>
#       <td id="T_0a12f_row5_col4" class="data row5 col4" >0.4984</td>
#       <td id="T_0a12f_row5_col5" class="data row5 col5" >0.4530</td>
#     </tr>
#     <tr>
#       <th id="T_0a12f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_0a12f_row6_col0" class="data row6 col0" >1.5055</td>
#       <td id="T_0a12f_row6_col1" class="data row6 col1" >5481.8889</td>
#       <td id="T_0a12f_row6_col2" class="data row6 col2" >18.0262</td>
#       <td id="T_0a12f_row6_col3" class="data row6 col3" >0.0187</td>
#       <td id="T_0a12f_row6_col4" class="data row6 col4" >0.0052</td>
#       <td id="T_0a12f_row6_col5" class="data row6 col5" >0.0078</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# <style type="text/css">
# #T_dbbc2_row5_col0, #T_dbbc2_row5_col1, #T_dbbc2_row5_col2, #T_dbbc2_row5_col3, #T_dbbc2_row5_col4, #T_dbbc2_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dbbc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbbc2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_dbbc2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dbbc2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dbbc2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_dbbc2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_dbbc2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbbc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbbc2_row0_col0" class="data row0 col0" >68.4399</td>
#       <td id="T_dbbc2_row0_col1" class="data row0 col1" >26489.4991</td>
#       <td id="T_dbbc2_row0_col2" class="data row0 col2" >162.7559</td>
#       <td id="T_dbbc2_row0_col3" class="data row0 col3" >0.1541</td>
#       <td id="T_dbbc2_row0_col4" class="data row0 col4" >0.5791</td>
#       <td id="T_dbbc2_row0_col5" class="data row0 col5" >0.5190</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbbc2_row1_col0" class="data row1 col0" >67.0566</td>
#       <td id="T_dbbc2_row1_col1" class="data row1 col1" >25141.4936</td>
#       <td id="T_dbbc2_row1_col2" class="data row1 col2" >158.5607</td>
#       <td id="T_dbbc2_row1_col3" class="data row1 col3" >0.1610</td>
#       <td id="T_dbbc2_row1_col4" class="data row1 col4" >0.5724</td>
#       <td id="T_dbbc2_row1_col5" class="data row1 col5" >0.5121</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbbc2_row2_col0" class="data row2 col0" >70.5035</td>
#       <td id="T_dbbc2_row2_col1" class="data row2 col1" >32905.0980</td>
#       <td id="T_dbbc2_row2_col2" class="data row2 col2" >181.3976</td>
#       <td id="T_dbbc2_row2_col3" class="data row2 col3" >0.1383</td>
#       <td id="T_dbbc2_row2_col4" class="data row2 col4" >0.5642</td>
#       <td id="T_dbbc2_row2_col5" class="data row2 col5" >0.5050</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbbc2_row3_col0" class="data row3 col0" >66.1774</td>
#       <td id="T_dbbc2_row3_col1" class="data row3 col1" >16459.0377</td>
#       <td id="T_dbbc2_row3_col2" class="data row3 col2" >128.2928</td>
#       <td id="T_dbbc2_row3_col3" class="data row3 col3" >0.2007</td>
#       <td id="T_dbbc2_row3_col4" class="data row3 col4" >0.5710</td>
#       <td id="T_dbbc2_row3_col5" class="data row3 col5" >0.5280</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbbc2_row4_col0" class="data row4 col0" >68.4986</td>
#       <td id="T_dbbc2_row4_col1" class="data row4 col1" >31318.7719</td>
#       <td id="T_dbbc2_row4_col2" class="data row4 col2" >176.9711</td>
#       <td id="T_dbbc2_row4_col3" class="data row4 col3" >0.1419</td>
#       <td id="T_dbbc2_row4_col4" class="data row4 col4" >0.5513</td>
#       <td id="T_dbbc2_row4_col5" class="data row4 col5" >0.5027</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_dbbc2_row5_col0" class="data row5 col0" >68.1352</td>
#       <td id="T_dbbc2_row5_col1" class="data row5 col1" >26462.7801</td>
#       <td id="T_dbbc2_row5_col2" class="data row5 col2" >161.5956</td>
#       <td id="T_dbbc2_row5_col3" class="data row5 col3" >0.1592</td>
#       <td id="T_dbbc2_row5_col4" class="data row5 col4" >0.5676</td>
#       <td id="T_dbbc2_row5_col5" class="data row5 col5" >0.5134</td>
#     </tr>
#     <tr>
#       <th id="T_dbbc2_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_dbbc2_row6_col0" class="data row6 col0" >1.4717</td>
#       <td id="T_dbbc2_row6_col1" class="data row6 col1" >5777.6377</td>
#       <td id="T_dbbc2_row6_col2" class="data row6 col2" >18.6985</td>
#       <td id="T_dbbc2_row6_col3" class="data row6 col3" >0.0223</td>
#       <td id="T_dbbc2_row6_col4" class="data row6 col4" >0.0094</td>
#       <td id="T_dbbc2_row6_col5" class="data row6 col5" >0.0093</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_b8a52_row5_col0, #T_b8a52_row5_col1, #T_b8a52_row5_col2, #T_b8a52_row5_col3, #T_b8a52_row5_col4, #T_b8a52_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b8a52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8a52_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b8a52_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b8a52_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b8a52_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b8a52_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b8a52_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8a52_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8a52_row0_col0" class="data row0 col0" >63.6614</td>
#       <td id="T_b8a52_row0_col1" class="data row0 col1" >25664.6016</td>
#       <td id="T_b8a52_row0_col2" class="data row0 col2" >160.2018</td>
#       <td id="T_b8a52_row0_col3" class="data row0 col3" >0.1804</td>
#       <td id="T_b8a52_row0_col4" class="data row0 col4" >0.5068</td>
#       <td id="T_b8a52_row0_col5" class="data row0 col5" >0.4561</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8a52_row1_col0" class="data row1 col0" >62.6479</td>
#       <td id="T_b8a52_row1_col1" class="data row1 col1" >23990.4541</td>
#       <td id="T_b8a52_row1_col2" class="data row1 col2" >154.8885</td>
#       <td id="T_b8a52_row1_col3" class="data row1 col3" >0.1994</td>
#       <td id="T_b8a52_row1_col4" class="data row1 col4" >0.4980</td>
#       <td id="T_b8a52_row1_col5" class="data row1 col5" >0.4573</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b8a52_row2_col0" class="data row2 col0" >66.3405</td>
#       <td id="T_b8a52_row2_col1" class="data row2 col1" >31428.6380</td>
#       <td id="T_b8a52_row2_col2" class="data row2 col2" >177.2812</td>
#       <td id="T_b8a52_row2_col3" class="data row2 col3" >0.1770</td>
#       <td id="T_b8a52_row2_col4" class="data row2 col4" >0.4987</td>
#       <td id="T_b8a52_row2_col5" class="data row2 col5" >0.4552</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b8a52_row3_col0" class="data row3 col0" >61.9203</td>
#       <td id="T_b8a52_row3_col1" class="data row3 col1" >15602.8724</td>
#       <td id="T_b8a52_row3_col2" class="data row3 col2" >124.9115</td>
#       <td id="T_b8a52_row3_col3" class="data row3 col3" >0.2423</td>
#       <td id="T_b8a52_row3_col4" class="data row3 col4" >0.4984</td>
#       <td id="T_b8a52_row3_col5" class="data row3 col5" >0.4723</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b8a52_row4_col0" class="data row4 col0" >64.2029</td>
#       <td id="T_b8a52_row4_col1" class="data row4 col1" >30017.7654</td>
#       <td id="T_b8a52_row4_col2" class="data row4 col2" >173.2564</td>
#       <td id="T_b8a52_row4_col3" class="data row4 col3" >0.1776</td>
#       <td id="T_b8a52_row4_col4" class="data row4 col4" >0.4908</td>
#       <td id="T_b8a52_row4_col5" class="data row4 col5" >0.4488</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b8a52_row5_col0" class="data row5 col0" >63.7546</td>
#       <td id="T_b8a52_row5_col1" class="data row5 col1" >25340.8663</td>
#       <td id="T_b8a52_row5_col2" class="data row5 col2" >158.1079</td>
#       <td id="T_b8a52_row5_col3" class="data row5 col3" >0.1953</td>
#       <td id="T_b8a52_row5_col4" class="data row5 col4" >0.4986</td>
#       <td id="T_b8a52_row5_col5" class="data row5 col5" >0.4579</td>
#     </tr>
#     <tr>
#       <th id="T_b8a52_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b8a52_row6_col0" class="data row6 col0" >1.5157</td>
#       <td id="T_b8a52_row6_col1" class="data row6 col1" >5580.1665</td>
#       <td id="T_b8a52_row6_col2" class="data row6 col2" >18.5140</td>
#       <td id="T_b8a52_row6_col3" class="data row6 col3" >0.0249</td>
#       <td id="T_b8a52_row6_col4" class="data row6 col4" >0.0051</td>
#       <td id="T_b8a52_row6_col5" class="data row6 col5" >0.0078</td>
#     </tr>
#   </tbody>
# </table>

# %%
model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['latitude', 'longitude',
#                                              'minimum_nights',
#                                              'number_of_reviews'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=Clean...
#                                                             n_jobs=-1,
#                                                             num_leaves=40,
#                                                             random_state=42,
#                                                             reg_alpha=2,
#                                                             reg_lambda=0.001)),
#                                              ('Gradient Boosting Regressor',
#                                               GradientBoostingRegressor(learning_rate=0.05,
#                                                                         max_depth=6,
#                                                                         max_features='sqrt',
#                                                                         min_impurity_decrease=0.0002,
#                                                                         min_samples_leaf=3,
#                                                                         min_samples_split=5,
#                                                                         n_estimators=120,
#                                                                         random_state=42,
#                                                                         subsample=0.65)),
#                                              ('Ridge Regression',
#                                               Ridge(random_state=42))],
#                                  n_jobs=-1))])

# %%
from sklearn.metrics import mean_squared_error

y_pred = predict_model(model, data=X_train)["prediction_label"]
print("Train data score:", mean_squared_error(y_train, y_pred))

y_pred = predict_model(model, data=X_test)["prediction_label"]
print("Test data score:", mean_squared_error(y_test, y_pred))
# Out:
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# Train data score: 25328.76009025393
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# Test data score: 47520.259942760786

# %% [markdown]
# ---
#
# - Baseline: 54244.32571482477
# - Final: 47520.259942760786
#
# 과제를 진행하면서 다양한 방법을 적용해보았는데 특히 pycaret을 처음 사용하면서 모델의 최적화를 시도해보았다.
# 다만 피쳐 엔지니어링 방법이 적절한지에 대해서는 아직 의문이 든다.
# 여러 코드를 보면서 방법에 대해서 비교해봐야할 것 같다.
